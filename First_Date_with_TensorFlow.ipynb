# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/k-manisha/Assignment-4/blob/k-manisha/First_Date_with_TensorFlow.ipynb)

# %% [markdown]
# # First Date with TensorFlow
#
# Hi all,<br/>
#
# You know what's important for understanding Deep Learning / Machine Learning?<br/>
# Intuition. Period.
#
# And Intuition comes when you run the code multiple times.
#
# So, today I can write a couple of defination and say this is this, this is that.<br/>
# You Google half of the things up. You find answers which you need to Google further.<br/>
# In the process, you probably won't even remember what's the first thing you started out with!
#
# So?
#
# Hence on, I will execute cells with code. <br/>
# The neurons in your brain will optimize a function to get a hold of what each function is doing.<br/>
# **No Theory Just Code.**
#
# I will at max give a defination that extends for a line. That's it.<br/>
# Let's get started!
#
# <hr/>
#
# **RECOMMENDED!**<br/>
# Write the code in the cells using the signals sent by your brain to your fingers!<br/>
# Don't just `shift+enter` the cells.
#
# [Source](https://github.com/iArunava/TensorFlow-NoteBooks)

# %%
# Essential imports
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Let's define some tensors
t1 = tf.constant(2.0, dtype=tf.float32)
t2 = tf.constant([1.0, 2.0], dtype=tf.float32)
t3 = tf.constant([[[1.0, 9.0], [2.0, 3.0], [4.0, 5.0]], 
                  [[1.0, 9.0], [2.0, 3.0], [4.0, 5.0]]])

# %%
# Let's print them out!
print (t1)
print (t2)
print (t3)
# Out:
# Tensor("Const:0", shape=(), dtype=float32)
# Tensor("Const_1:0", shape=(2,), dtype=float32)
# Tensor("Const_2:0", shape=(2, 3, 2), dtype=float32)

# %% [markdown]
# Where's Waldo?<br/>
# I mean, the value?<br/>
#
# So, the thing is you can't print the value of tensors directly.<br/>
# You have to use `session`, so let's do that!

# %%
sess = tf.Session()
print (sess.run(t1))
print ("=======================")
print (sess.run(t2))
print ("=======================")
print (sess.run(t3))
sess.close()
# Out:
# 2.0
# =======================
# [1. 2.]
# =======================
# [[[1. 9.]
#   [2. 3.]
#   [4. 5.]]
#
#  [[1. 9.]
#   [2. 3.]
#   [4. 5.]]]

# %% [markdown]
# Aaahaa!! Just printed those tensors!!!<br/>
# Feels good! <br/>
#
# For some of you, who are like, dude you got "No Theory Just Code" in bold <br/>
# And you are still using the markdown cells for the theory ?!
#
# I am just gonna say I am a unreasonable man.<br/>
#
#
# So, you are programming with tf.<br/>
# What ever you do is broken down to 2 basic steps:
# - Building the computational Graph!
# - Execute that graph using `session`!
#
# That's all!
#
# <hr/>
#
# Let's compare this 2 steps with what we did above!<br/>
# So, I defined 3 `tensor`s and these 3 `tensor`s formed my computational Graph.<br/>
# And then I executed each tensor in this graph using a `session`.
#
# That simple!
#
# <hr/>
#
# Now, let's define a few more computational graphs and execute them with sessions.
#
# Okay, to start with let's build this computational graph!
#
# ![Comp Graph 1](https://raw.githubusercontent.com/iArunava/TensorFlow-NoteBooks/master/assets/comp_graph_1.jpg)

# %%
# Let's define the graph
comp_graph_1 = tf.multiply(tf.add(78, 19), 79)

# Alternatively
comp_graph_1_alt = (tf.constant(78) + tf.constant(19)) * tf.constant(79)

# Let's execute using session
sess = tf.Session()
print ('Comp Graph 1    : ', sess.run(comp_graph_1))
print ('Comp Graph 1 Alt: ', sess.run(comp_graph_1_alt))
sess.close()
# Out:
# Comp Graph 1    :  7663
# Comp Graph 1 Alt:  7663

# %% [markdown]
# Let's define a sligtly more involved graph!
#
# ![alt text](https://raw.githubusercontent.com/iArunava/TensorFlow-NoteBooks/master/assets/comp_graph_2.jpg)

# %%
# Let build the graph
# We need to cast cause the tensors operated on should be of the same type
comp_graph_part_1 = tf.cast(tf.subtract(tf.add(7, 8), tf.add(9, 10)), 
                            dtype=tf.float32)
comp_graph_part_2 = tf.divide(tf.cast(tf.multiply(7, 10), dtype=tf.float32), tf.constant(19.5))
comp_graph_complete = tf.maximum(comp_graph_part_1, comp_graph_part_2)

# Let's execute
sess = tf.Session()
part1_res, part2_res, total_res = sess.run([comp_graph_part_1, comp_graph_part_2, comp_graph_complete])
print ('Complete Result: ', total_res)
print ('Part 1 Result: ', part1_res)
print ('Part 2 Result: ', part2_res)
sess.close()
# Out:
# Complete Result:  3.5897436
# Part 1 Result:  -4.0
# Part 2 Result:  3.5897436

# %% [markdown]
# Cool! Let's go! Build another graph and execute it with sessions.<br/>
#
# But this time, it's all you!
#
# Build this graph and execute it with `session`!
#
# ![alt text](https://raw.githubusercontent.com/iArunava/TensorFlow-NoteBooks/master/assets/comp_graph_3.jpg)
#
# _Remember that `tensors` operated on should be of the same type!_<br/>
# _Search up errors and other help you need on Google_

# %%
# Build the graph
# YOUR CODE HERE
node_1=tf.constant([9,10],dtype=tf.float32, name='leaf_node1')
node_2=tf.constant([7,8.65],dtype=tf.float32, name='leaf_node2')
node_3=tf.constant(5.6,dtype=tf.float32, name='leaf_node3')
node_4=tf.constant([7.65,9.0],dtype=tf.float32, name='leaf_node4')
node_5=tf.constant([13.5,7.18],dtype=tf.float32, name='leaf_node5')
cg= tf.minimum(((node_1 * node_2)/ node_3),(node_4 + node_5))
# Execute 
# YOUR CODE HERE
with tf.Session() as sess:
  print(sess.run(cg))
# Out:
# [11.25     15.446429]

# %% [markdown]
# Let's do another!<br/>
# It's fun! Isn't it?!
#
# Build and execute this one!
#
# ![alt text](https://raw.githubusercontent.com/iArunava/TensorFlow-NoteBooks/master/assets/comp_graph_4.jpg)

# %%
# Build the graph
node_1= tf.constant([[1.2,3.4],[7.5,8.6]], dtype=tf.float32)
node_2 = tf.constant([[7.0,9.0],[8.0,6.0]], dtype=tf.float32)
node_3= tf.constant([[2.79,3.81,5.6],[7.3,5.67,8.9]],dtype=tf.float32)
node_4= tf.constant([[2.6,18.1],[7.86,9.81],[9.36,10.41]], dtype=tf.float32)
cg_2= tf.reduce_mean(node_1, axis=1)
cg_2= tf.reshape(cg_2,[1,2])

cg_3= tf.matmul(node_3,node_4)
cg_4= tf.reduce_sum(cg_3)
cg_5=tf.matmul(cg_2,node_2)
cg_6 = cg_5 + cg_4

# if Transposed, use tf.multiply to multiply corresponding elements, else tf.matmul for matrix multiplication
cg_t=tf.add(tf.multiply(tf.reduce_mean(node_1,axis=1),node_2) , tf.reduce_sum(tf.multiply(node_3, tf.transpose(node_4))))

# Execute 
# YOUR CODE HERE
sess= tf.Session()
print(sess.run(cg_2))
print(sess.run(cg_3))
print(sess.run(cg_4))
print(sess.run(cg_5))
print('Final ans')
print(sess.run(cg_6))

print('Ans with Transpose used \n', sess.run(cg_t))

sess.close()
# Out:
# [[2.3000002 8.05     ]]
# [[ 89.6166  146.1711 ]
#  [146.85019 280.4017 ]]
# 663.03955
# [[80.5 69. ]]
# Final ans
# [[743.53955 732.03955]]
# Ans with Transpose used
#  [[386.1183  442.4683 ]
#  [388.41827 418.3183 ]]

# %% [markdown]
# And a final one, before we move on to the next part!
#
# ![alt text](https://raw.githubusercontent.com/iArunava/TensorFlow-NoteBooks/master/assets/comp_graph_5.jpg)

# %%
# Build the graph
# YOUR CODE HERE
node_1 = tf.constant([[7.36,8.91,10.41],[5.31,9.38,7.99]], dtype=tf.float32)
node_2 = tf.constant([[7.99,10.36],[5.36,7.98],[8.91,5.67]], dtype= tf.float32)
node_3 = tf.constant([[1,5.6,6.1,8],[0,0,7.98,9],[0,0,7.6,7],[0,0,0,7.98]], dtype= tf.float32)
cg_1=tf.divide(tf.add(tf.reduce_sum(tf.matmul(node_1,node_2)),tf.constant(7.0)), tf.constant(19.6))
#if Transpose is there then (2,3) and (2,3) shaped matrices's corresponsing elements are multiplied 
cg_2= tf.divide(tf.add(tf.reduce_sum(node_1 * tf.transpose(node_2)),tf.constant(7.0)), tf.constant(19.6))
cg_3 = tf.divide(cg_1, node_3)
cg_4 = tf.divide(cg_2, node_3)

# Execute 
# YOUR CODE HERE
with tf.Session() as sess:
  print('Without Transpose')
  print(sess.run(cg_3))
  print('With transpose')
  print(sess.run(cg_4))
# Out:
# Without Transpose
# [[38.35485    6.8490806  6.2876806  4.7943563]
#  [       inf        inf  4.806372   4.26165  ]
#  [       inf        inf  5.046691   5.4792643]
#  [       inf        inf        inf  4.806372 ]]
# With transpose
# [[19.463488   3.475623   3.1907358  2.432936 ]
#  [       inf        inf  2.4390335  2.1626098]
#  [       inf        inf  2.5609853  2.7804983]
#  [       inf        inf        inf  2.4390335]]

# %% [markdown]
# # Linear Regression
#
# Okay, now we will create a dummy dataset and perform linear regression on this dataset!
#
#
# To get you in the habit of looking up for the documentation, I am not providing what some of the following functions does, Google them up!

# %%
# Create the dataset
X = np.linspace(-30.0, 300.0, 300)
Y = 2 * np.linspace(-30.0, 250.0, 300) + np.random.randn(*X.shape)

# Divide it into train and test
train_X = X[:250]
train_Y = Y[:250]

test_X = X[250:]
test_Y = Y[250:]

# %%
# Let's define the hyperparameters
learning_rate = 0.000005
n_epochs = 1000
interval = 50

# %%
# let's viz the first 10 datapoints of the dataset
plt.plot(train_X[:10], train_Y[:10], 'g')
plt.show()

# %% [markdown]
# ** Question **<br/>
# Why did I created a session to plot the graph?<br/>
# [Ans] So that we can see the noise. With very large range we get to see just a straight line

# %%
# Let's define the placeholders

# Placeholders?
# The input to the model changes on iteration
# So we cannot have a constant in the input as we did before
# And thus we need placeholders which we can change on each 
# iteration of the training

x = tf.placeholder(tf.float32, name='x')
y = tf.placeholder(tf.float32, name='y')

# %%
# Let's define the linear regression model

# tf.Variable?
# We define the model parameters as tf.Variables
# as they get updated throghout the training.
# And variables denotes something which changes overtime.

W = tf.Variable(0.0, name='weight_1')
b = tf.Variable(0.0, name='bias_1')

pred_y = (W*x) + b

# %%
# Let's define the loss function
# We are going to use the mean squared loss
loss = tf.reduce_mean(tf.square(y - pred_y))

# %%
# Let's define the optimizer
# And specify the which value (i.e. loss) it has to minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(loss)

# %%
# So the graph is now built
# Now let's execute the graph using session
# i.e. lets train the model

# What it is to train a model?
# To update the paramters in the graph (i.e. tf.Variables)
# So that the loss is minimized

# Okay let's start!
with tf.Session() as sess:
  # We need to initialize the variables in our graph
  sess.run(tf.global_variables_initializer())
  
  for epoch in range(n_epochs):
    _, curr_loss = sess.run([optimizer, loss], feed_dict={x:train_X, y:train_Y})
    
    if epoch % interval == 0:
      print ('Loss after epoch', epoch, ' is ', curr_loss)
    
  print ('Now testing the model in the test set')
  final_preds, final_loss = sess.run([pred_y, loss], feed_dict={x:test_X, y:test_Y})
    
  print ('The final loss is: ', final_loss)
  
  # Plotting the final predictions against the true predictions
  plt.plot(test_X[:10], test_Y[:10], 'g', label='True Function')
  plt.plot(test_X[:10], final_preds[:10], 'r', label='Predicted Function')
  plt.legend()
  plt.show()
# Out:
# Loss after epoch 0  is  48337.715
# Loss after epoch 50  is  30.661478
# Loss after epoch 100  is  30.650763
# Loss after epoch 150  is  30.640217
# Loss after epoch 200  is  30.62964
# Loss after epoch 250  is  30.619144
# Loss after epoch 300  is  30.60858
# Loss after epoch 350  is  30.59804
# Loss after epoch 400  is  30.58751
# Loss after epoch 450  is  30.576965
# Loss after epoch 500  is  30.566433
# Loss after epoch 550  is  30.555956
# Loss after epoch 600  is  30.54543
# Loss after epoch 650  is  30.534885
# Loss after epoch 700  is  30.524384
# Loss after epoch 750  is  30.51388
# Loss after epoch 800  is  30.503366
# Loss after epoch 850  is  30.492855
# Loss after epoch 900  is  30.482347
# Loss after epoch 950  is  30.471857
# Now testing the model in the test set
# The final loss is:  33.904423

# %% [markdown]
# Okay, so we are doing good!<br/>
#
# Now, let me just put everything here into one function so that you can tweak the hyperparameters easily!
#
# Or better, do it yourself!

# %%
def linear_regression(learning_rate=0.000005, n_epochs=100, interval=50):
  # YOUR CODE HERE
 
  x = tf.placeholder(tf.float32, name='x')
  y = tf.placeholder(tf.float32, name='y')
  
  W = tf.Variable(0.0, name='weight_1')
  b = tf.Variable(0.0, name='bias_1')

  pred_y = (W*x) + b
  
  loss = tf.reduce_mean(tf.square(y - pred_y))
  
  optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(loss)
  
  with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for epoch in range(n_epochs):
      _, curr_loss = sess.run([optimizer, loss], feed_dict={x:train_X, y:train_Y})
      
      if epoch % interval == 0:
        print ('Loss after epoch', epoch, ' is ', curr_loss)
    print ('Now testing the model in the test set')
    final_preds, final_loss = sess.run([pred_y, loss], feed_dict={x:test_X, y:test_Y})
    
    print ('The final loss is: ', final_loss)
    
    # Plotting the final predictions against the true predictions
    plt.plot(test_X[:10], test_Y[:10], 'g', label='True Function')
    plt.plot(test_X[:10], final_preds[:10], 'r', label='Predicted Function')
    plt.legend()
    plt.show()
    
  pass

# %%
# Okay! Now let's tweak!
linear_regression(learning_rate=0.000034, n_epochs=500)
# Out:
# Loss after epoch 0  is  48337.715
# Loss after epoch 50  is  30.600128
# Loss after epoch 100  is  30.528587
# Loss after epoch 150  is  30.457216
# Loss after epoch 200  is  30.385962
# Loss after epoch 250  is  30.314907
# Loss after epoch 300  is  30.244055
# Loss after epoch 350  is  30.173332
# Loss after epoch 400  is  30.10281
# Loss after epoch 450  is  30.03247
# Now testing the model in the test set
# The final loss is:  33.334293

# %%
linear_regression(learning_rate=0.0000006, n_epochs=1000)
# Out:
# Loss after epoch 0  is  48337.715
# Loss after epoch 50  is  5551.129
# Loss after epoch 100  is  661.5371
# Loss after epoch 150  is  102.76307
# Loss after epoch 200  is  38.90572
# Loss after epoch 250  is  31.60704
# Loss after epoch 300  is  30.771856
# Loss after epoch 350  is  30.675287
# Loss after epoch 400  is  30.663166
# Loss after epoch 450  is  30.660643
# Loss after epoch 500  is  30.659218
# Loss after epoch 550  is  30.657951
# Loss after epoch 600  is  30.656677
# Loss after epoch 650  is  30.655434
# Loss after epoch 700  is  30.654142
# Loss after epoch 750  is  30.652866
# Loss after epoch 800  is  30.651625
# Loss after epoch 850  is  30.650354
# Loss after epoch 900  is  30.649061
# Loss after epoch 950  is  30.647816
# Now testing the model in the test set
# The final loss is:  34.121185

# %% [markdown]
# ## Drive the loss to a minimum.

# %%
# YOUR CODE HERE
linear_regression(learning_rate=0.000005, n_epochs=2000)
# Out:
# Loss after epoch 0  is  48337.715
# Loss after epoch 50  is  30.661478
# Loss after epoch 100  is  30.650763
# Loss after epoch 150  is  30.640217
# Loss after epoch 200  is  30.62964
# Loss after epoch 250  is  30.619144
# Loss after epoch 300  is  30.60858
# Loss after epoch 350  is  30.59804
# Loss after epoch 400  is  30.58751
# Loss after epoch 450  is  30.576965
# Loss after epoch 500  is  30.566433
# Loss after epoch 550  is  30.555956
# Loss after epoch 600  is  30.54543
# Loss after epoch 650  is  30.534885
# Loss after epoch 700  is  30.524384
# Loss after epoch 750  is  30.51388
# Loss after epoch 800  is  30.503366
# Loss after epoch 850  is  30.492855
# Loss after epoch 900  is  30.482347
# Loss after epoch 950  is  30.471857
# Loss after epoch 1000  is  30.46141
# Loss after epoch 1050  is  30.450926
# Loss after epoch 1100  is  30.440445
# Loss after epoch 1150  is  30.429962
# Loss after epoch 1200  is  30.419493
# Loss after epoch 1250  is  30.409018
# Loss after epoch 1300  is  30.398561
# Loss after epoch 1350  is  30.388092
# Loss after epoch 1400  is  30.377626
# Loss after epoch 1450  is  30.367172
# Loss after epoch 1500  is  30.356731
# Loss after epoch 1550  is  30.346275
# Loss after epoch 1600  is  30.335829
# Loss after epoch 1650  is  30.325348
# Loss after epoch 1700  is  30.31491
# Loss after epoch 1750  is  30.304476
# Loss after epoch 1800  is  30.29407
# Loss after epoch 1850  is  30.283638
# Loss after epoch 1900  is  30.273222
# Loss after epoch 1950  is  30.262796
# Now testing the model in the test set
# The final loss is:  33.66557

# %%
linear_regression(learning_rate=0.00005, n_epochs=500)
# Out:
# Loss after epoch 0  is  48337.715
# Loss after epoch 50  is  30.566427
# Loss after epoch 100  is  30.461409
# Loss after epoch 150  is  30.356714
# Loss after epoch 200  is  30.252384
# Loss after epoch 250  is  30.148434
# Loss after epoch 300  is  30.044834
# Loss after epoch 350  is  29.941654
# Loss after epoch 400  is  29.838783
# Loss after epoch 450  is  29.736317
# Now testing the model in the test set
# The final loss is:  32.95923

# %%
linear_regression(learning_rate=0.00009, n_epochs=1000)
# Out:
# Loss after epoch 0  is  48337.715
# Loss after epoch 50  is  inf
# Loss after epoch 100  is  nan
# Loss after epoch 150  is  nan
# Loss after epoch 200  is  nan
# Loss after epoch 250  is  nan
# Loss after epoch 300  is  nan
# Loss after epoch 350  is  nan
# Loss after epoch 400  is  nan
# Loss after epoch 450  is  nan
# Loss after epoch 500  is  nan
# Loss after epoch 550  is  nan
# Loss after epoch 600  is  nan
# Loss after epoch 650  is  nan
# Loss after epoch 700  is  nan
# Loss after epoch 750  is  nan
# Loss after epoch 800  is  nan
# Loss after epoch 850  is  nan
# Loss after epoch 900  is  nan
# Loss after epoch 950  is  nan
# Now testing the model in the test set
# The final loss is:  nan

# %%
linear_regression(learning_rate=0.00004, n_epochs=10000, interval=1000)
# Out:
# Loss after epoch 0  is  48337.715
# Loss after epoch 1000  is  29.029003
# Loss after epoch 2000  is  27.476791
# Loss after epoch 3000  is  26.010233
# Loss after epoch 4000  is  24.624617
# Loss after epoch 5000  is  23.315466
# Loss after epoch 6000  is  22.078548
# Loss after epoch 7000  is  20.909927
# Loss after epoch 8000  is  19.80577
# Loss after epoch 9000  is  18.762539
# Now testing the model in the test set
# The final loss is:  19.479504

# %%
linear_regression(learning_rate=0.0000525, n_epochs=10000, interval= 1000)
# Out:
# Loss after epoch 0  is  48337.715
# Loss after epoch 1000  is  28.53445
# Loss after epoch 2000  is  26.550434
# Loss after epoch 3000  is  24.708889
# Loss after epoch 4000  is  22.999601
# Loss after epoch 5000  is  21.412996
# Loss after epoch 6000  is  19.940346
# Loss after epoch 7000  is  18.573431
# Loss after epoch 8000  is  17.30462
# Loss after epoch 9000  is  16.126968
# Now testing the model in the test set
# The final loss is:  16.384602

# %%
linear_regression(learning_rate=0.0000535, n_epochs=10000, interval= 1000)
# Out:
# Loss after epoch 0  is  48337.715
# Loss after epoch 1000  is  28.495262
# Loss after epoch 2000  is  26.477726
# Loss after epoch 3000  is  24.607761
# Loss after epoch 4000  is  22.87451
# Loss after epoch 5000  is  21.26798
# Loss after epoch 6000  is  19.778917
# Loss after epoch 7000  is  18.398752
# Loss after epoch 8000  is  17.119444
# Loss after epoch 9000  is  15.93373
# Now testing the model in the test set
# The final loss is:  16.160517

# %%
linear_regression(learning_rate=0.0000525, n_epochs=90000, interval= 10000)
# Out:
# Loss after epoch 0  is  48337.715
# Loss after epoch 10000  is  15.033832
# Loss after epoch 20000  is  7.6105213
# Loss after epoch 30000  is  4.0867233
# Loss after epoch 40000  is  2.4139798
# Loss after epoch 50000  is  1.6199572
# Loss after epoch 60000  is  1.2430247
# Loss after epoch 70000  is  1.0640943
# Loss after epoch 80000  is  0.97919065
# Now testing the model in the test set
# The final loss is:  1.1911502
