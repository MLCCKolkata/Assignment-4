# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/ShreyashiSaha/Assignment-4/blob/ShreyashiSaha/First_Date_with_TensorFlow.ipynb)

# %% [markdown]
# # First Date with TensorFlow
#
# Hi all,<br/>
#
# You know what's important for understanding Deep Learning / Machine Learning?<br/>
# Intuition. Period.
#
# And Intuition comes when you run the code multiple times.
#
# So, today I can write a couple of defination and say this is this, this is that.<br/>
# You Google half of the things up. You find answers which you need to Google further.<br/>
# In the process, you probably won't even remember what's the first thing you started out with!
#
# So?
#
# Hence on, I will execute cells with code. <br/>
# The neurons in your brain will optimize a function to get a hold of what each function is doing.<br/>
# **No Theory Just Code.**
#
# I will at max give a defination that extends for a line. That's it.<br/>
# Let's get started!
#
# <hr/>
#
# **RECOMMENDED!**<br/>
# Write the code in the cells using the signals sent by your brain to your fingers!<br/>
# Don't just `shift+enter` the cells.
#
# [Source](https://github.com/iArunava/TensorFlow-NoteBooks)

# %%
# Essential imports
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Let's define some tensors
t1 = tf.constant(2.0, dtype=tf.float32)
t2 = tf.constant([1.0, 2.0], dtype=tf.float32)
t3 = tf.constant([[[1.0, 9.0], [2.0, 3.0], [4.0, 5.0]], 
                  [[1.0, 9.0], [2.0, 3.0], [4.0, 5.0]]])

# %%
# Let's print them out!
print (t1)
print (t2)
print (t3)
# Out:
# Tensor("Const:0", shape=(), dtype=float32)
# Tensor("Const_1:0", shape=(2,), dtype=float32)
# Tensor("Const_2:0", shape=(2, 3, 2), dtype=float32)

# %% [markdown]
# Where's Waldo?<br/>
# I mean, the value?<br/>
#
# So, the thing is you can't print the value of tensors directly.<br/>
# You have to use `session`, so let's do that!

# %%
sess = tf.Session()
print (sess.run(t1))
print ("=======================")
print (sess.run(t2))
print ("=======================")
print (sess.run(t3))
sess.close()
# Out:
# 2.0
# =======================
# [1. 2.]
# =======================
# [[[1. 9.]
#   [2. 3.]
#   [4. 5.]]
#
#  [[1. 9.]
#   [2. 3.]
#   [4. 5.]]]

# %% [markdown]
# Aaahaa!! Just printed those tensors!!!<br/>
# Feels good! <br/>
#
# For some of you, who are like, dude you got "No Theory Just Code" in bold <br/>
# And you are still using the markdown cells for the theory ?!
#
# I am just gonna say I am a unreasonable man.<br/>
#
#
# So, you are programming with tf.<br/>
# What ever you do is broken down to 2 basic steps:
# - Building the computational Graph!
# - Execute that graph using `session`!
#
# That's all!
#
# <hr/>
#
# Let's compare this 2 steps with what we did above!<br/>
# So, I defined 3 `tensor`s and these 3 `tensor`s formed my computational Graph.<br/>
# And then I executed each tensor in this graph using a `session`.
#
# That simple!
#
# <hr/>
#
# Now, let's define a few more computational graphs and execute them with sessions.
#
# Okay, to start with let's build this computational graph!
#
# ![Comp Graph 1](https://raw.githubusercontent.com/iArunava/TensorFlow-NoteBooks/master/assets/comp_graph_1.jpg)

# %%
# Let's define the graph
comp_graph_1 = tf.multiply(tf.add(78, 19), 79)

# Alternatively
comp_graph_1_alt = (tf.constant(78) + tf.constant(19)) * tf.constant(79)

# Let's execute using session
sess = tf.Session()
print ('Comp Graph 1    : ', sess.run(comp_graph_1))
print ('Comp Graph 1 Alt: ', sess.run(comp_graph_1_alt))
sess.close()
# Out:
# Comp Graph 1    :  7663
# Comp Graph 1 Alt:  7663

# %% [markdown]
# Let's define a sligtly more involved graph!
#
# ![alt text](https://raw.githubusercontent.com/iArunava/TensorFlow-NoteBooks/master/assets/comp_graph_2.jpg)

# %%
# Let build the graph
# We need to cast cause the tensors operated on should be of the same type
comp_graph_part_1 = tf.cast(tf.subtract(tf.add(7, 8), tf.add(9, 10)), 
                            dtype=tf.float32)
comp_graph_part_2 = tf.divide(tf.cast(tf.multiply(7, 10), dtype=tf.float32), tf.constant(19.5))
comp_graph_complete = tf.maximum(comp_graph_part_1, comp_graph_part_2)

# Let's execute
sess = tf.Session()
part1_res, part2_res, total_res = sess.run([comp_graph_part_1, comp_graph_part_2, comp_graph_complete])
print ('Complete Result: ', total_res)
print ('Part 1 Result: ', part1_res)
print ('Part 2 Result: ', part2_res)
sess.close()
# Out:
# Complete Result:  3.5897436
# Part 1 Result:  -4.0
# Part 2 Result:  3.5897436

# %% [markdown]
# Cool! Let's go! Build another graph and execute it with sessions.<br/>
#
# But this time, it's all you!
#
# Build this graph and execute it with `session`!
#
# ![alt text](https://raw.githubusercontent.com/iArunava/TensorFlow-NoteBooks/master/assets/comp_graph_3.jpg)
#
# _Remember that `tensors` operated on should be of the same type!_<br/>
# _Search up errors and other help you need on Google_

# %%
# Build the graph
# YOUR CODE HERE
cg=tf.minimum(tf.divide(tf.multiply(tf.constant([9,10],dtype=tf.float32),[7,8.65]),5.6),tf.add([7.65,9],[13.5,7.18]))
# Execute 
# YOUR CODE HERE
with tf.Session() as sess:
  print(sess.run(cg))
# Out:
# [11.25     15.446429]

# %% [markdown]
# Let's do another!<br/>
# It's fun! Isn't it?!
#
# Build and execute this one!
#
# ![alt text](https://raw.githubusercontent.com/iArunava/TensorFlow-NoteBooks/master/assets/comp_graph_4.jpg)

# %%
# Build the graph
# YOUR CODE HERE
matrix_1=tf.constant([[1.2,3.4],[7.5,8.6]])
matrix_2=tf.constant([[7,9],[8,6]],dtype=tf.float32)
matrix_3=tf.constant([[2.79,3.81,5.6],[7.3,5.67,8.9]])
matrix_4=tf.constant([[2.6,18.1],[7.86,9.81],[9.36,10.11]])


# Execute 
# YOUR CODE HERE
cg=tf.add(tf.multiply(tf.reduce_mean(matrix_1,1),matrix_2),tf.reduce_sum(tf.multiply(matrix_3,tf.transpose(matrix_4))))
with tf.Session() as sess:
  print("Result",sess.run(cg))
# Out:
# Result [[383.4483  439.7983 ]
#  [385.7483  415.64832]]

# %% [markdown]
# And a final one, before we move on to the next part!
#
# ![alt text](https://raw.githubusercontent.com/iArunava/TensorFlow-NoteBooks/master/assets/comp_graph_5.jpg)

# %%
# Build the graph
# YOUR CODE HERE
t1=tf.constant([[7.36,8.91,10.41],[5.31,9.38,7.99]])
t2=tf.constant([[7.99,10.36],[5.36,7.98],[8.91,5.67]])
t3=tf.constant([[1,5.6,6.1,8],[0,0,7.98,9],[0,0,7.6,7],[0,0,0,8.98]])

# Execute 
# YOUR CODE HERE
cg_2=tf.divide(tf.divide(tf.add(7.0,tf.reduce_sum(tf.multiply(t1,tf.transpose(t2)))),19.6),t3)
with tf.Session() as sess:
  print("Result")
  print(sess.run(cg_2))
# Out:
# Result
# [[19.463488   3.475623   3.1907358  2.432936 ]
#  [       inf        inf  2.4390335  2.1626098]
#  [       inf        inf  2.5609853  2.7804983]
#  [       inf        inf        inf  2.1674263]]

# %% [markdown]
# # Linear Regression
#
# Okay, now we will create a dummy dataset and perform linear regression on this dataset!
#
#
# To get you in the habit of looking up for the documentation, I am not providing what some of the following functions does, Google them up!

# %%
# Create the dataset
X = np.linspace(-30.0, 300.0, 300)
Y = 2 * np.linspace(-30.0, 250.0, 300) + np.random.randn(*X.shape)

# Divide it into train and test
train_X = X[:250]
train_Y = Y[:250]

test_X = X[250:]
test_Y = Y[250:]

# %%
# Let's define the hyperparameters
learning_rate = 0.000005
n_epochs = 1000
interval = 50

# %%
# let's viz the first 10 datapoints of the dataset
plt.plot(train_X[:10], train_Y[:10], 'g')
plt.show()

# %% [markdown]
# ** Question **<br/>
# Why did I created a session to plot the graph?<br/>
# [Ans]

# %% [markdown]
# Because you did not use tensorflow to create the model

# %%
# Let's define the placeholders

# Placeholders?
# The input to the model changes on iteration
# So we cannot have a constant in the input as we did before
# And thus we need placeholders which we can change on each 
# iteration of the training

x = tf.placeholder(tf.float32, name='x')
y = tf.placeholder(tf.float32, name='y')

# %%
# Let's define the linear regression model

# tf.Variable?
# We define the model parameters as tf.Variables
# as they get updated throghout the training.
# And variables denotes something which changes overtime.

W = tf.Variable(0.0, name='weight_1')
b = tf.Variable(0.0, name='bias_1')

pred_y = (W*x) + b

# %%
# Let's define the loss function
# We are going to use the mean squared loss
loss = tf.reduce_mean(tf.square(y - pred_y))

# %%
# Let's define the optimizer
# And specify the which value (i.e. loss) it has to minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(loss)

# %%
# So the graph is now built
# Now let's execute the graph using session
# i.e. lets train the model

# What it is to train a model?
# To update the paramters in the graph (i.e. tf.Variables)
# So that the loss is minimized

# Okay let's start!
with tf.Session() as sess:
  # We need to initialize the variables in our graph
  sess.run(tf.global_variables_initializer())
  
  for epoch in range(n_epochs):
    _, curr_loss = sess.run([optimizer, loss], feed_dict={x:train_X, y:train_Y})
    
    if epoch % interval == 0:
      print ('Loss after epoch', epoch, ' is ', curr_loss)
    
  print ('Now testing the model in the test set')
  final_preds, final_loss = sess.run([pred_y, loss], feed_dict={x:test_X, y:test_Y})
    
  print ('The final loss is: ', final_loss)
  
  # Plotting the final predictions against the true predictions
  plt.plot(test_X[:10], test_Y[:10], 'g', label='True Function')
  plt.plot(test_X[:10], final_preds[:10], 'r', label='Predicted Function')
  plt.legend()
  plt.show()
# Out:
# Loss after epoch 0  is  48217.832
# Loss after epoch 50  is  30.771576
# Loss after epoch 100  is  30.760841
# Loss after epoch 150  is  30.750278
# Loss after epoch 200  is  30.7397
# Loss after epoch 250  is  30.729107
# Loss after epoch 300  is  30.718569
# Loss after epoch 350  is  30.707983
# Loss after epoch 400  is  30.697422
# Loss after epoch 450  is  30.686838
# Loss after epoch 500  is  30.67633
# Loss after epoch 550  is  30.665756
# Loss after epoch 600  is  30.655207
# Loss after epoch 650  is  30.644638
# Loss after epoch 700  is  30.634092
# Loss after epoch 750  is  30.623592
# Loss after epoch 800  is  30.613049
# Loss after epoch 850  is  30.602512
# Loss after epoch 900  is  30.591982
# Loss after epoch 950  is  30.581453
# Now testing the model in the test set
# The final loss is:  39.50356

# %% [markdown]
# Okay, so we are doing good!<br/>
#
# Now, let me just put everything here into one function so that you can tweak the hyperparameters easily!
#
# Or better, do it yourself!

# %%
def linear_regression(learning_rate=0.000005, n_epochs=100, interval=50):
  # YOUR CODE HERE
  x = tf.placeholder(tf.float32, name='x')
  y = tf.placeholder(tf.float32, name='y')
  W = tf.Variable(0.0, name='weight_1')
  b = tf.Variable(0.0, name='bias_1')

  pred_y = (W*x) + b
  loss = tf.reduce_mean(tf.square(y - pred_y))
  optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(loss)
  with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
  
    for epoch in range(n_epochs):
      _, curr_loss = sess.run([optimizer, loss], feed_dict={x:train_X, y:train_Y})

      if epoch % interval == 0:
        print ('Loss after epoch', epoch, ' is ', curr_loss)

    print ('Now testing the model in the test set')
    final_preds, final_loss = sess.run([pred_y, loss], feed_dict={x:test_X, y:test_Y})

    print ('The final loss is: ', final_loss)

    plt.plot(test_X[:10], test_Y[:10], 'g', label='True Function')
    plt.plot(test_X[:10], final_preds[:10], 'r', label='Predicted Function')
    plt.legend()
    plt.show()

# %%
# Okay! Now let's tweak!
linear_regression(learning_rate=0.000034, n_epochs=500)
# Out:
# Loss after epoch 0  is  48217.832
# Loss after epoch 50  is  30.710096
# Loss after epoch 100  is  30.638332
# Loss after epoch 150  is  30.566757
# Loss after epoch 200  is  30.495338
# Loss after epoch 250  is  30.424055
# Loss after epoch 300  is  30.353016
# Loss after epoch 350  is  30.282074
# Loss after epoch 400  is  30.211382
# Loss after epoch 450  is  30.140816
# Now testing the model in the test set
# The final loss is:  38.88496

# %%
linear_regression(learning_rate=0.0000006, n_epochs=1000)
# Out:
# Loss after epoch 0  is  48217.832
# Loss after epoch 50  is  5537.527
# Loss after epoch 100  is  660.08136
# Loss after epoch 150  is  102.693985
# Loss after epoch 200  is  38.995316
# Loss after epoch 250  is  31.714823
# Loss after epoch 300  is  30.881762
# Loss after epoch 350  is  30.785408
# Loss after epoch 400  is  30.773272
# Loss after epoch 450  is  30.770737
# Loss after epoch 500  is  30.769348
# Loss after epoch 550  is  30.768042
# Loss after epoch 600  is  30.766808
# Loss after epoch 650  is  30.76552
# Loss after epoch 700  is  30.76422
# Loss after epoch 750  is  30.762978
# Loss after epoch 800  is  30.761703
# Loss after epoch 850  is  30.760448
# Loss after epoch 900  is  30.759174
# Loss after epoch 950  is  30.757874
# Now testing the model in the test set
# The final loss is:  39.738842

# %% [markdown]
# ## Drive the loss to a minimum.

# %%
# YOUR CODE HERE
linear_regression(learning_rate=0.000045, n_epochs=45000)
# Out:
# Loss after epoch 0  is  48217.832
# Loss after epoch 50  is  30.686838
# Loss after epoch 100  is  30.591988
# Loss after epoch 150  is  30.497417
# Loss after epoch 200  is  30.40313
# Loss after epoch 250  is  30.309183
# Loss after epoch 300  is  30.215528
# Loss after epoch 350  is  30.122122
# Loss after epoch 400  is  30.029078
# Loss after epoch 450  is  29.936296
# Loss after epoch 500  is  29.84383
# Loss after epoch 550  is  29.751646
# Loss after epoch 600  is  29.659735
# Loss after epoch 650  is  29.56814
# Loss after epoch 700  is  29.476828
# Loss after epoch 750  is  29.385822
# Loss after epoch 800  is  29.29509
# Loss after epoch 850  is  29.204638
# Loss after epoch 900  is  29.114513
# Loss after epoch 950  is  29.024652
# Loss after epoch 1000  is  28.93508
# Loss after epoch 1050  is  28.845814
# Loss after epoch 1100  is  28.75677
# Loss after epoch 1150  is  28.668049
# Loss after epoch 1200  is  28.57965
# Loss after epoch 1250  is  28.491474
# Loss after epoch 1300  is  28.403631
# Loss after epoch 1350  is  28.316004
# Loss after epoch 1400  is  28.228704
# Loss after epoch 1450  is  28.141684
# Loss after epoch 1500  is  28.05488
# Loss after epoch 1550  is  27.9684
# Loss after epoch 1600  is  27.882221
# Loss after epoch 1650  is  27.796268
# Loss after epoch 1700  is  27.710606
# Loss after epoch 1750  is  27.625261
# Loss after epoch 1800  is  27.540136
# Loss after epoch 1850  is  27.455303
# Loss after epoch 1900  is  27.370718
# Loss after epoch 1950  is  27.286427
# Loss after epoch 2000  is  27.202408
# Loss after epoch 2050  is  27.118599
# Loss after epoch 2100  is  27.035147
# Loss after epoch 2150  is  26.951897
# Loss after epoch 2200  is  26.868944
# Loss after epoch 2250  is  26.786245
# Loss after epoch 2300  is  26.703789
# Loss after epoch 2350  is  26.62164
# Loss after epoch 2400  is  26.539696
# Loss after epoch 2450  is  26.458038
# Loss after epoch 2500  is  26.376661
# Loss after epoch 2550  is  26.29555
# Loss after epoch 2600  is  26.21468
# Loss after epoch 2650  is  26.134039
# Loss after epoch 2700  is  26.053709
# Loss after epoch 2750  is  25.973562
# Loss after epoch 2800  is  25.893755
# Loss after epoch 2850  is  25.814148
# Loss after epoch 2900  is  25.734812
# Loss after epoch 2950  is  25.655733
# Loss after epoch 3000  is  25.576876
# Loss after epoch 3050  is  25.498318
# Loss after epoch 3100  is  25.419987
# Loss after epoch 3150  is  25.341923
# Loss after epoch 3200  is  25.26407
# Loss after epoch 3250  is  25.18649
# Loss after epoch 3300  is  25.109135
# Loss after epoch 3350  is  25.032057
# Loss after epoch 3400  is  24.955221
# Loss after epoch 3450  is  24.878616
# Loss after epoch 3500  is  24.802244
# Loss after epoch 3550  is  24.72615
# Loss after epoch 3600  is  24.65027
# Loss after epoch 3650  is  24.574654
# Loss after epoch 3700  is  24.499292
# Loss after epoch 3750  is  24.424135
# Loss after epoch 3800  is  24.349216
# Loss after epoch 3850  is  24.274569
# Loss after epoch 3900  is  24.200117
# Loss after epoch 3950  is  24.125923
# Loss after epoch 4000  is  24.051973
# Loss after epoch 4050  is  23.97826
# Loss after epoch 4100  is  23.904762
# Loss after epoch 4150  is  23.831526
# Loss after epoch 4200  is  23.758493
# Loss after epoch 4250  is  23.685713
# Loss after epoch 4300  is  23.613167
# Loss after epoch 4350  is  23.540848
# Loss after epoch 4400  is  23.468752
# Loss after epoch 4450  is  23.396893
# Loss after epoch 4500  is  23.325264
# Loss after epoch 4550  is  23.253857
# Loss after epoch 4600  is  23.182688
# Loss after epoch 4650  is  23.111734
# Loss after epoch 4700  is  23.041008
# Loss after epoch 4750  is  22.970512
# Loss after epoch 4800  is  22.900236
# Loss after epoch 4850  is  22.830181
# Loss after epoch 4900  is  22.760366
# Loss after epoch 4950  is  22.690773
# Loss after epoch 5000  is  22.621365
# Loss after epoch 5050  is  22.552227
# Loss after epoch 5100  is  22.48328
# Loss after epoch 5150  is  22.414574
# Loss after epoch 5200  is  22.34609
# Loss after epoch 5250  is  22.277803
# Loss after epoch 5300  is  22.209723
# Loss after epoch 5350  is  22.141878
# Loss after epoch 5400  is  22.074234
# Loss after epoch 5450  is  22.006834
# Loss after epoch 5500  is  21.939634
# Loss after epoch 5550  is  21.872656
# Loss after epoch 5600  is  21.80589
# Loss after epoch 5650  is  21.739332
# Loss after epoch 5700  is  21.67297
# Loss after epoch 5750  is  21.606838
# Loss after epoch 5800  is  21.540916
# Loss after epoch 5850  is  21.475182
# Loss after epoch 5900  is  21.409695
# Loss after epoch 5950  is  21.344383
# Loss after epoch 6000  is  21.27931
# Loss after epoch 6050  is  21.214441
# Loss after epoch 6100  is  21.149757
# Loss after epoch 6150  is  21.085306
# Loss after epoch 6200  is  21.021038
# Loss after epoch 6250  is  20.956968
# Loss after epoch 6300  is  20.89312
# Loss after epoch 6350  is  20.829464
# Loss after epoch 6400  is  20.766005
# Loss after epoch 6450  is  20.70276
# Loss after epoch 6500  is  20.639751
# Loss after epoch 6550  is  20.576893
# Loss after epoch 6600  is  20.514252
# Loss after epoch 6650  is  20.451834
# Loss after epoch 6700  is  20.389553
# Loss after epoch 6750  is  20.327545
# Loss after epoch 6800  is  20.265682
# Loss after epoch 6850  is  20.204031
# Loss after epoch 6900  is  20.142572
# Loss after epoch 6950  is  20.081322
# Loss after epoch 7000  is  20.020267
# Loss after epoch 7050  is  19.959414
# Loss after epoch 7100  is  19.898706
# Loss after epoch 7150  is  19.83826
# Loss after epoch 7200  is  19.777943
# Loss after epoch 7250  is  19.717855
# Loss after epoch 7300  is  19.657976
# Loss after epoch 7350  is  19.59827
# Loss after epoch 7400  is  19.538748
# Loss after epoch 7450  is  19.479391
# Loss after epoch 7500  is  19.420246
# Loss after epoch 7550  is  19.361319
# Loss after epoch 7600  is  19.302525
# Loss after epoch 7650  is  19.243977
# Loss after epoch 7700  is  19.185558
# Loss after epoch 7750  is  19.12737
# Loss after epoch 7800  is  19.069357
# Loss after epoch 7850  is  19.011496
# Loss after epoch 7900  is  18.953876
# Loss after epoch 7950  is  18.896399
# Loss after epoch 8000  is  18.839117
# Loss after epoch 8050  is  18.782026
# Loss after epoch 8100  is  18.72507
# Loss after epoch 8150  is  18.66837
# Loss after epoch 8200  is  18.611786
# Loss after epoch 8250  is  18.55541
# Loss after epoch 8300  is  18.499226
# Loss after epoch 8350  is  18.44322
# Loss after epoch 8400  is  18.387375
# Loss after epoch 8450  is  18.331728
# Loss after epoch 8500  is  18.276224
# Loss after epoch 8550  is  18.220913
# Loss after epoch 8600  is  18.165777
# Loss after epoch 8650  is  18.110851
# Loss after epoch 8700  is  18.05604
# Loss after epoch 8750  is  18.001467
# Loss after epoch 8800  is  17.947014
# Loss after epoch 8850  is  17.892757
# Loss after epoch 8900  is  17.838686
# Loss after epoch 8950  is  17.784788
# Loss after epoch 9000  is  17.731033
# Loss after epoch 9050  is  17.67748
# Loss after epoch 9100  is  17.624067
# Loss after epoch 9150  is  17.570827
# Loss after epoch 9200  is  17.517801
# Loss after epoch 9250  is  17.464895
# Loss after epoch 9300  is  17.41218
# Loss after epoch 9350  is  17.359625
# Loss after epoch 9400  is  17.30724
# Loss after epoch 9450  is  17.255028
# Loss after epoch 9500  is  17.202988
# Loss after epoch 9550  is  17.151104
# Loss after epoch 9600  is  17.099371
# Loss after epoch 9650  is  17.047823
# Loss after epoch 9700  is  16.996414
# Loss after epoch 9750  is  16.945206
# Loss after epoch 9800  is  16.894123
# Loss after epoch 9850  is  16.843239
# Loss after epoch 9900  is  16.792486
# Loss after epoch 9950  is  16.74193
# Loss after epoch 10000  is  16.691513
# Loss after epoch 10050  is  16.641256
# Loss after epoch 10100  is  16.59117
# Loss after epoch 10150  is  16.541212
# Loss after epoch 10200  is  16.49146
# Loss after epoch 10250  is  16.441824
# Loss after epoch 10300  is  16.392385
# Loss after epoch 10350  is  16.343084
# Loss after epoch 10400  is  16.29394
# Loss after epoch 10450  is  16.24496
# Loss after epoch 10500  is  16.196121
# Loss after epoch 10550  is  16.147448
# Loss after epoch 10600  is  16.098944
# Loss after epoch 10650  is  16.050554
# Loss after epoch 10700  is  16.002369
# Loss after epoch 10750  is  15.954282
# Loss after epoch 10800  is  15.906412
# Loss after epoch 10850  is  15.858644
# Loss after epoch 10900  is  15.811031
# Loss after epoch 10950  is  15.7636
# Loss after epoch 11000  is  15.716294
# Loss after epoch 11050  is  15.669146
# Loss after epoch 11100  is  15.622151
# Loss after epoch 11150  is  15.575324
# Loss after epoch 11200  is  15.528637
# Loss after epoch 11250  is  15.482077
# Loss after epoch 11300  is  15.435688
# Loss after epoch 11350  is  15.389428
# Loss after epoch 11400  is  15.343336
# Loss after epoch 11450  is  15.297367
# Loss after epoch 11500  is  15.251579
# Loss after epoch 11550  is  15.205908
# Loss after epoch 11600  is  15.160368
# Loss after epoch 11650  is  15.114995
# Loss after epoch 11700  is  15.0697775
# Loss after epoch 11750  is  15.024698
# Loss after epoch 11800  is  14.979746
# Loss after epoch 11850  is  14.934943
# Loss after epoch 11900  is  14.890308
# Loss after epoch 11950  is  14.845799
# Loss after epoch 12000  is  14.801422
# Loss after epoch 12050  is  14.757203
# Loss after epoch 12100  is  14.713098
# Loss after epoch 12150  is  14.669154
# Loss after epoch 12200  is  14.625377
# Loss after epoch 12250  is  14.581683
# Loss after epoch 12300  is  14.538174
# Loss after epoch 12350  is  14.494764
# Loss after epoch 12400  is  14.451541
# Loss after epoch 12450  is  14.408401
# Loss after epoch 12500  is  14.365459
# Loss after epoch 12550  is  14.322594
# Loss after epoch 12600  is  14.279914
# Loss after epoch 12650  is  14.237334
# Loss after epoch 12700  is  14.194898
# Loss after epoch 12750  is  14.15261
# Loss after epoch 12800  is  14.110449
# Loss after epoch 12850  is  14.068428
# Loss after epoch 12900  is  14.026532
# Loss after epoch 12950  is  13.984788
# Loss after epoch 13000  is  13.943168
# Loss after epoch 13050  is  13.90166
# Loss after epoch 13100  is  13.860287
# Loss after epoch 13150  is  13.819074
# Loss after epoch 13200  is  13.777981
# Loss after epoch 13250  is  13.737027
# Loss after epoch 13300  is  13.696188
# Loss after epoch 13350  is  13.655465
# Loss after epoch 13400  is  13.61489
# Loss after epoch 13450  is  13.574447
# Loss after epoch 13500  is  13.53414
# Loss after epoch 13550  is  13.493963
# Loss after epoch 13600  is  13.453901
# Loss after epoch 13650  is  13.413948
# Loss after epoch 13700  is  13.37414
# Loss after epoch 13750  is  13.334476
# Loss after epoch 13800  is  13.294923
# Loss after epoch 13850  is  13.255499
# Loss after epoch 13900  is  13.216196
# Loss after epoch 13950  is  13.177039
# Loss after epoch 14000  is  13.137989
# Loss after epoch 14050  is  13.099038
# Loss after epoch 14100  is  13.060238
# Loss after epoch 14150  is  13.021574
# Loss after epoch 14200  is  12.983009
# Loss after epoch 14250  is  12.9445915
# Loss after epoch 14300  is  12.906268
# Loss after epoch 14350  is  12.868095
# Loss after epoch 14400  is  12.830032
# Loss after epoch 14450  is  12.792089
# Loss after epoch 14500  is  12.754257
# Loss after epoch 14550  is  12.716567
# Loss after epoch 14600  is  12.678973
# Loss after epoch 14650  is  12.64151
# Loss after epoch 14700  is  12.604196
# Loss after epoch 14750  is  12.566948
# Loss after epoch 14800  is  12.529859
# Loss after epoch 14850  is  12.49287
# Loss after epoch 14900  is  12.455998
# Loss after epoch 14950  is  12.41925
# Loss after epoch 15000  is  12.3826275
# Loss after epoch 15050  is  12.346109
# Loss after epoch 15100  is  12.309688
# Loss after epoch 15150  is  12.2734
# Loss after epoch 15200  is  12.237245
# Loss after epoch 15250  is  12.201197
# Loss after epoch 15300  is  12.165266
# Loss after epoch 15350  is  12.129428
# Loss after epoch 15400  is  12.093736
# Loss after epoch 15450  is  12.05813
# Loss after epoch 15500  is  12.02266
# Loss after epoch 15550  is  11.987273
# Loss after epoch 15600  is  11.952021
# Loss after epoch 15650  is  11.916876
# Loss after epoch 15700  is  11.881848
# Loss after epoch 15750  is  11.84694
# Loss after epoch 15800  is  11.81213
# Loss after epoch 15850  is  11.777421
# Loss after epoch 15900  is  11.742835
# Loss after epoch 15950  is  11.708364
# Loss after epoch 16000  is  11.673989
# Loss after epoch 16050  is  11.639742
# Loss after epoch 16100  is  11.6055765
# Loss after epoch 16150  is  11.571555
# Loss after epoch 16200  is  11.537611
# Loss after epoch 16250  is  11.503801
# Loss after epoch 16300  is  11.4700775
# Loss after epoch 16350  is  11.436468
# Loss after epoch 16400  is  11.40298
# Loss after epoch 16450  is  11.369582
# Loss after epoch 16500  is  11.336282
# Loss after epoch 16550  is  11.303108
# Loss after epoch 16600  is  11.270028
# Loss after epoch 16650  is  11.23706
# Loss after epoch 16700  is  11.204192
# Loss after epoch 16750  is  11.171425
# Loss after epoch 16800  is  11.138778
# Loss after epoch 16850  is  11.106243
# Loss after epoch 16900  is  11.073797
# Loss after epoch 16950  is  11.041441
# Loss after epoch 17000  is  11.009195
# Loss after epoch 17050  is  10.977063
# Loss after epoch 17100  is  10.945024
# Loss after epoch 17150  is  10.913089
# Loss after epoch 17200  is  10.881264
# Loss after epoch 17250  is  10.849532
# Loss after epoch 17300  is  10.817893
# Loss after epoch 17350  is  10.786366
# Loss after epoch 17400  is  10.754948
# Loss after epoch 17450  is  10.723616
# Loss after epoch 17500  is  10.692398
# Loss after epoch 17550  is  10.661257
# Loss after epoch 17600  is  10.630242
# Loss after epoch 17650  is  10.599306
# Loss after epoch 17700  is  10.568472
# Loss after epoch 17750  is  10.537726
# Loss after epoch 17800  is  10.507092
# Loss after epoch 17850  is  10.476566
# Loss after epoch 17900  is  10.446116
# Loss after epoch 17950  is  10.415782
# Loss after epoch 18000  is  10.385524
# Loss after epoch 18050  is  10.355385
# Loss after epoch 18100  is  10.32533
# Loss after epoch 18150  is  10.295391
# Loss after epoch 18200  is  10.265484
# Loss after epoch 18250  is  10.235735
# Loss after epoch 18300  is  10.20605
# Loss after epoch 18350  is  10.176496
# Loss after epoch 18400  is  10.146997
# Loss after epoch 18450  is  10.117625
# Loss after epoch 18500  is  10.088326
# Loss after epoch 18550  is  10.059133
# Loss after epoch 18600  is  10.03003
# Loss after epoch 18650  is  10.001009
# Loss after epoch 18700  is  9.97208
# Loss after epoch 18750  is  9.943232
# Loss after epoch 18800  is  9.914511
# Loss after epoch 18850  is  9.885832
# Loss after epoch 18900  is  9.857304
# Loss after epoch 18950  is  9.828816
# Loss after epoch 19000  is  9.800463
# Loss after epoch 19050  is  9.77216
# Loss after epoch 19100  is  9.743969
# Loss after epoch 19150  is  9.715874
# Loss after epoch 19200  is  9.687861
# Loss after epoch 19250  is  9.659939
# Loss after epoch 19300  is  9.632097
# Loss after epoch 19350  is  9.604356
# Loss after epoch 19400  is  9.576693
# Loss after epoch 19450  is  9.549134
# Loss after epoch 19500  is  9.521614
# Loss after epoch 19550  is  9.494255
# Loss after epoch 19600  is  9.46693
# Loss after epoch 19650  is  9.439718
# Loss after epoch 19700  is  9.412568
# Loss after epoch 19750  is  9.38555
# Loss after epoch 19800  is  9.358559
# Loss after epoch 19850  is  9.331711
# Loss after epoch 19900  is  9.304901
# Loss after epoch 19950  is  9.278201
# Loss after epoch 20000  is  9.251583
# Loss after epoch 20050  is  9.225049
# Loss after epoch 20100  is  9.1986065
# Loss after epoch 20150  is  9.17223
# Loss after epoch 20200  is  9.1459465
# Loss after epoch 20250  is  9.119756
# Loss after epoch 20300  is  9.093644
# Loss after epoch 20350  is  9.067593
# Loss after epoch 20400  is  9.04166
# Loss after epoch 20450  is  9.015791
# Loss after epoch 20500  is  8.990004
# Loss after epoch 20550  is  8.964317
# Loss after epoch 20600  is  8.938689
# Loss after epoch 20650  is  8.913154
# Loss after epoch 20700  is  8.88771
# Loss after epoch 20750  is  8.862311
# Loss after epoch 20800  is  8.837022
# Loss after epoch 20850  is  8.811803
# Loss after epoch 20900  is  8.786698
# Loss after epoch 20950  is  8.761634
# Loss after epoch 21000  is  8.736654
# Loss after epoch 21050  is  8.711774
# Loss after epoch 21100  is  8.686949
# Loss after epoch 21150  is  8.662214
# Loss after epoch 21200  is  8.63757
# Loss after epoch 21250  is  8.612995
# Loss after epoch 21300  is  8.588495
# Loss after epoch 21350  is  8.564066
# Loss after epoch 21400  is  8.539726
# Loss after epoch 21450  is  8.515446
# Loss after epoch 21500  is  8.491279
# Loss after epoch 21550  is  8.46715
# Loss after epoch 21600  is  8.443122
# Loss after epoch 21650  is  8.419168
# Loss after epoch 21700  is  8.395293
# Loss after epoch 21750  is  8.371485
# Loss after epoch 21800  is  8.347746
# Loss after epoch 21850  is  8.324093
# Loss after epoch 21900  is  8.300527
# Loss after epoch 21950  is  8.277014
# Loss after epoch 22000  is  8.253584
# Loss after epoch 22050  is  8.230244
# Loss after epoch 22100  is  8.206964
# Loss after epoch 22150  is  8.183771
# Loss after epoch 22200  is  8.160625
# Loss after epoch 22250  is  8.137578
# Loss after epoch 22300  is  8.114586
# Loss after epoch 22350  is  8.091684
# Loss after epoch 22400  is  8.068836
# Loss after epoch 22450  is  8.046073
# Loss after epoch 22500  is  8.023384
# Loss after epoch 22550  is  8.000768
# Loss after epoch 22600  is  7.978206
# Loss after epoch 22650  is  7.95576
# Loss after epoch 22700  is  7.933345
# Loss after epoch 22750  is  7.91103
# Loss after epoch 22800  is  7.8887525
# Loss after epoch 22850  is  7.866569
# Loss after epoch 22900  is  7.8444333
# Loss after epoch 22950  is  7.8224006
# Loss after epoch 23000  is  7.800416
# Loss after epoch 23050  is  7.7785215
# Loss after epoch 23100  is  7.756672
# Loss after epoch 23150  is  7.734911
# Loss after epoch 23200  is  7.7131953
# Loss after epoch 23250  is  7.691567
# Loss after epoch 23300  is  7.6700096
# Loss after epoch 23350  is  7.6485043
# Loss after epoch 23400  is  7.6271114
# Loss after epoch 23450  is  7.605726
# Loss after epoch 23500  is  7.584471
# Loss after epoch 23550  is  7.5632257
# Loss after epoch 23600  is  7.5420895
# Loss after epoch 23650  is  7.5209928
# Loss after epoch 23700  is  7.4999824
# Loss after epoch 23750  is  7.479031
# Loss after epoch 23800  is  7.458154
# Loss after epoch 23850  is  7.4373326
# Loss after epoch 23900  is  7.416574
# Loss after epoch 23950  is  7.395893
# Loss after epoch 24000  is  7.3752766
# Loss after epoch 24050  is  7.3547235
# Loss after epoch 24100  is  7.3342266
# Loss after epoch 24150  is  7.313821
# Loss after epoch 24200  is  7.293456
# Loss after epoch 24250  is  7.273173
# Loss after epoch 24300  is  7.252939
# Loss after epoch 24350  is  7.2327747
# Loss after epoch 24400  is  7.2126846
# Loss after epoch 24450  is  7.192632
# Loss after epoch 24500  is  7.1726837
# Loss after epoch 24550  is  7.1527495
# Loss after epoch 24600  is  7.132933
# Loss after epoch 24650  is  7.1131387
# Loss after epoch 24700  is  7.093432
# Loss after epoch 24750  is  7.0737696
# Loss after epoch 24800  is  7.054173
# Loss after epoch 24850  is  7.0346622
# Loss after epoch 24900  is  7.015194
# Loss after epoch 24950  is  6.9957876
# Loss after epoch 25000  is  6.9764185
# Loss after epoch 25050  is  6.9571643
# Loss after epoch 25100  is  6.9379425
# Loss after epoch 25150  is  6.918791
# Loss after epoch 25200  is  6.899672
# Loss after epoch 25250  is  6.8806453
# Loss after epoch 25300  is  6.8616743
# Loss after epoch 25350  is  6.8427486
# Loss after epoch 25400  is  6.823906
# Loss after epoch 25450  is  6.805086
# Loss after epoch 25500  is  6.786379
# Loss after epoch 25550  is  6.7677026
# Loss after epoch 25600  is  6.749094
# Loss after epoch 25650  is  6.7305236
# Loss after epoch 25700  is  6.7120314
# Loss after epoch 25750  is  6.6936016
# Loss after epoch 25800  is  6.675207
# Loss after epoch 25850  is  6.6568937
# Loss after epoch 25900  is  6.6386228
# Loss after epoch 25950  is  6.620433
# Loss after epoch 26000  is  6.6022744
# Loss after epoch 26050  is  6.5841846
# Loss after epoch 26100  is  6.5661697
# Loss after epoch 26150  is  6.5481653
# Loss after epoch 26200  is  6.5302734
# Loss after epoch 26250  is  6.512406
# Loss after epoch 26300  is  6.4946074
# Loss after epoch 26350  is  6.4768605
# Loss after epoch 26400  is  6.459167
# Loss after epoch 26450  is  6.4415393
# Loss after epoch 26500  is  6.423967
# Loss after epoch 26550  is  6.406449
# Loss after epoch 26600  is  6.388992
# Loss after epoch 26650  is  6.3715796
# Loss after epoch 26700  is  6.354216
# Loss after epoch 26750  is  6.336911
# Loss after epoch 26800  is  6.3196864
# Loss after epoch 26850  is  6.3024907
# Loss after epoch 26900  is  6.285363
# Loss after epoch 26950  is  6.268283
# Loss after epoch 27000  is  6.2512503
# Loss after epoch 27050  is  6.234288
# Loss after epoch 27100  is  6.217365
# Loss after epoch 27150  is  6.2005076
# Loss after epoch 27200  is  6.1837068
# Loss after epoch 27250  is  6.166945
# Loss after epoch 27300  is  6.1502595
# Loss after epoch 27350  is  6.133592
# Loss after epoch 27400  is  6.117017
# Loss after epoch 27450  is  6.1004677
# Loss after epoch 27500  is  6.0839763
# Loss after epoch 27550  is  6.067559
# Loss after epoch 27600  is  6.051159
# Loss after epoch 27650  is  6.0348387
# Loss after epoch 27700  is  6.018557
# Loss after epoch 27750  is  6.002318
# Loss after epoch 27800  is  5.9861565
# Loss after epoch 27850  is  5.970022
# Loss after epoch 27900  is  5.953968
# Loss after epoch 27950  is  5.9379177
# Loss after epoch 28000  is  5.9219694
# Loss after epoch 28050  is  5.9060454
# Loss after epoch 28100  is  5.8901644
# Loss after epoch 28150  is  5.8743625
# Loss after epoch 28200  is  5.858571
# Loss after epoch 28250  is  5.8428717
# Loss after epoch 28300  is  5.8272123
# Loss after epoch 28350  is  5.811579
# Loss after epoch 28400  is  5.796023
# Loss after epoch 28450  is  5.780505
# Loss after epoch 28500  is  5.765033
# Loss after epoch 28550  is  5.7496166
# Loss after epoch 28600  is  5.7342396
# Loss after epoch 28650  is  5.71893
# Loss after epoch 28700  is  5.7036467
# Loss after epoch 28750  is  5.688428
# Loss after epoch 28800  is  5.6732564
# Loss after epoch 28850  is  5.658121
# Loss after epoch 28900  is  5.6430516
# Loss after epoch 28950  is  5.6280155
# Loss after epoch 29000  is  5.613035
# Loss after epoch 29050  is  5.5981045
# Loss after epoch 29100  is  5.5832047
# Loss after epoch 29150  is  5.5683775
# Loss after epoch 29200  is  5.5535865
# Loss after epoch 29250  is  5.5388327
# Loss after epoch 29300  is  5.5241485
# Loss after epoch 29350  is  5.5094743
# Loss after epoch 29400  is  5.4948864
# Loss after epoch 29450  is  5.4803395
# Loss after epoch 29500  is  5.4658065
# Loss after epoch 29550  is  5.4513564
# Loss after epoch 29600  is  5.4369392
# Loss after epoch 29650  is  5.422554
# Loss after epoch 29700  is  5.4082394
# Loss after epoch 29750  is  5.393942
# Loss after epoch 29800  is  5.3797197
# Loss after epoch 29850  is  5.365527
# Loss after epoch 29900  is  5.3513713
# Loss after epoch 29950  is  5.3372946
# Loss after epoch 30000  is  5.32322
# Loss after epoch 30050  is  5.3092103
# Loss after epoch 30100  is  5.2952614
# Loss after epoch 30150  is  5.2813163
# Loss after epoch 30200  is  5.267454
# Loss after epoch 30250  is  5.253619
# Loss after epoch 30300  is  5.239828
# Loss after epoch 30350  is  5.2260947
# Loss after epoch 30400  is  5.212389
# Loss after epoch 30450  is  5.1987185
# Loss after epoch 30500  is  5.185115
# Loss after epoch 30550  is  5.1715384
# Loss after epoch 30600  is  5.158008
# Loss after epoch 30650  is  5.1445346
# Loss after epoch 30700  is  5.131075
# Loss after epoch 30750  is  5.117696
# Loss after epoch 30800  is  5.1043463
# Loss after epoch 30850  is  5.0910215
# Loss after epoch 30900  is  5.0777555
# Loss after epoch 30950  is  5.0645266
# Loss after epoch 31000  is  5.0513334
# Loss after epoch 31050  is  5.0381927
# Loss after epoch 31100  is  5.0250897
# Loss after epoch 31150  is  5.0120363
# Loss after epoch 31200  is  4.999015
# Loss after epoch 31250  is  4.986037
# Loss after epoch 31300  is  4.9731097
# Loss after epoch 31350  is  4.9602165
# Loss after epoch 31400  is  4.9473495
# Loss after epoch 31450  is  4.9345555
# Loss after epoch 31500  is  4.921777
# Loss after epoch 31550  is  4.9090433
# Loss after epoch 31600  is  4.8963585
# Loss after epoch 31650  is  4.883694
# Loss after epoch 31700  is  4.871088
# Loss after epoch 31750  is  4.8585205
# Loss after epoch 31800  is  4.8459897
# Loss after epoch 31850  is  4.8335114
# Loss after epoch 31900  is  4.8210697
# Loss after epoch 31950  is  4.808636
# Loss after epoch 32000  is  4.7962914
# Loss after epoch 32050  is  4.7839465
# Loss after epoch 32100  is  4.771657
# Loss after epoch 32150  is  4.7594185
# Loss after epoch 32200  is  4.7471833
# Loss after epoch 32250  is  4.7350135
# Loss after epoch 32300  is  4.722891
# Loss after epoch 32350  is  4.710786
# Loss after epoch 32400  is  4.6987348
# Loss after epoch 32450  is  4.6867156
# Loss after epoch 32500  is  4.674715
# Loss after epoch 32550  is  4.6627884
# Loss after epoch 32600  is  4.6508923
# Loss after epoch 32650  is  4.639003
# Loss after epoch 32700  is  4.6271896
# Loss after epoch 32750  is  4.615398
# Loss after epoch 32800  is  4.6036353
# Loss after epoch 32850  is  4.591934
# Loss after epoch 32900  is  4.5802555
# Loss after epoch 32950  is  4.5685825
# Loss after epoch 33000  is  4.5570097
# Loss after epoch 33050  is  4.5454345
# Loss after epoch 33100  is  4.533887
# Loss after epoch 33150  is  4.5224056
# Loss after epoch 33200  is  4.510954
# Loss after epoch 33250  is  4.499519
# Loss after epoch 33300  is  4.4881544
# Loss after epoch 33350  is  4.4767914
# Loss after epoch 33400  is  4.465478
# Loss after epoch 33450  is  4.45422
# Loss after epoch 33500  is  4.44296
# Loss after epoch 33550  is  4.431756
# Loss after epoch 33600  is  4.4206
# Loss after epoch 33650  is  4.4094625
# Loss after epoch 33700  is  4.398358
# Loss after epoch 33750  is  4.3873034
# Loss after epoch 33800  is  4.376283
# Loss after epoch 33850  is  4.365284
# Loss after epoch 33900  is  4.3543344
# Loss after epoch 33950  is  4.3434134
# Loss after epoch 34000  is  4.3325152
# Loss after epoch 34050  is  4.3216763
# Loss after epoch 34100  is  4.310843
# Loss after epoch 34150  is  4.3000603
# Loss after epoch 34200  is  4.289323
# Loss after epoch 34250  is  4.278606
# Loss after epoch 34300  is  4.267919
# Loss after epoch 34350  is  4.257283
# Loss after epoch 34400  is  4.2466693
# Loss after epoch 34450  is  4.2360787
# Loss after epoch 34500  is  4.225539
# Loss after epoch 34550  is  4.2150383
# Loss after epoch 34600  is  4.2045426
# Loss after epoch 34650  is  4.194123
# Loss after epoch 34700  is  4.183699
# Loss after epoch 34750  is  4.173311
# Loss after epoch 34800  is  4.162984
# Loss after epoch 34850  is  4.152679
# Loss after epoch 34900  is  4.142371
# Loss after epoch 34950  is  4.1321526
# Loss after epoch 35000  is  4.1219425
# Loss after epoch 35050  is  4.1117477
# Loss after epoch 35100  is  4.1016026
# Loss after epoch 35150  is  4.091484
# Loss after epoch 35200  is  4.0814023
# Loss after epoch 35250  is  4.0713453
# Loss after epoch 35300  is  4.0613375
# Loss after epoch 35350  is  4.051341
# Loss after epoch 35400  is  4.0413775
# Loss after epoch 35450  is  4.031471
# Loss after epoch 35500  is  4.021577
# Loss after epoch 35550  is  4.011705
# Loss after epoch 35600  is  4.0018883
# Loss after epoch 35650  is  3.9920838
# Loss after epoch 35700  is  3.982308
# Loss after epoch 35750  is  3.9725852
# Loss after epoch 35800  is  3.9628823
# Loss after epoch 35850  is  3.9531922
# Loss after epoch 35900  is  3.9435718
# Loss after epoch 35950  is  3.933954
# Loss after epoch 36000  is  3.9243608
# Loss after epoch 36050  is  3.9148178
# Loss after epoch 36100  is  3.9053102
# Loss after epoch 36150  is  3.8958063
# Loss after epoch 36200  is  3.8863409
# Loss after epoch 36250  is  3.8769267
# Loss after epoch 36300  is  3.8675191
# Loss after epoch 36350  is  3.8581343
# Loss after epoch 36400  is  3.8488083
# Loss after epoch 36450  is  3.8394957
# Loss after epoch 36500  is  3.8302002
# Loss after epoch 36550  is  3.8209796
# Loss after epoch 36600  is  3.8117547
# Loss after epoch 36650  is  3.8025517
# Loss after epoch 36700  is  3.7933953
# Loss after epoch 36750  is  3.7842672
# Loss after epoch 36800  is  3.7751606
# Loss after epoch 36850  is  3.766081
# Loss after epoch 36900  is  3.7570355
# Loss after epoch 36950  is  3.7480235
# Loss after epoch 37000  is  3.7390242
# Loss after epoch 37050  is  3.7300804
# Loss after epoch 37100  is  3.7211382
# Loss after epoch 37150  is  3.7122247
# Loss after epoch 37200  is  3.7033708
# Loss after epoch 37250  is  3.694527
# Loss after epoch 37300  is  3.6857026
# Loss after epoch 37350  is  3.6769102
# Loss after epoch 37400  is  3.6681519
# Loss after epoch 37450  is  3.6594126
# Loss after epoch 37500  is  3.6506877
# Loss after epoch 37550  is  3.6420288
# Loss after epoch 37600  is  3.6333747
# Loss after epoch 37650  is  3.6247478
# Loss after epoch 37700  is  3.6161592
# Loss after epoch 37750  is  3.607596
# Loss after epoch 37800  is  3.5990562
# Loss after epoch 37850  is  3.5905285
# Loss after epoch 37900  is  3.582056
# Loss after epoch 37950  is  3.5735936
# Loss after epoch 38000  is  3.5651462
# Loss after epoch 38050  is  3.5567482
# Loss after epoch 38100  is  3.5483735
# Loss after epoch 38150  is  3.5400243
# Loss after epoch 38200  is  3.5316994
# Loss after epoch 38250  is  3.5234027
# Loss after epoch 38300  is  3.5151238
# Loss after epoch 38350  is  3.5068667
# Loss after epoch 38400  is  3.498653
# Loss after epoch 38450  is  3.4904726
# Loss after epoch 38500  is  3.4822996
# Loss after epoch 38550  is  3.4741511
# Loss after epoch 38600  is  3.4660485
# Loss after epoch 38650  is  3.4579594
# Loss after epoch 38700  is  3.4498699
# Loss after epoch 38750  is  3.4418597
# Loss after epoch 38800  is  3.4338498
# Loss after epoch 38850  is  3.425854
# Loss after epoch 38900  is  3.417879
# Loss after epoch 38950  is  3.4099636
# Loss after epoch 39000  is  3.4020443
# Loss after epoch 39050  is  3.3941405
# Loss after epoch 39100  is  3.386298
# Loss after epoch 39150  is  3.378464
# Loss after epoch 39200  is  3.3706517
# Loss after epoch 39250  is  3.3628595
# Loss after epoch 39300  is  3.3551126
# Loss after epoch 39350  is  3.3473778
# Loss after epoch 39400  is  3.3396492
# Loss after epoch 39450  is  3.331968
# Loss after epoch 39500  is  3.3243108
# Loss after epoch 39550  is  3.3166728
# Loss after epoch 39600  is  3.3090496
# Loss after epoch 39650  is  3.3014722
# Loss after epoch 39700  is  3.2939057
# Loss after epoch 39750  is  3.286365
# Loss after epoch 39800  is  3.278839
# Loss after epoch 39850  is  3.2713654
# Loss after epoch 39900  is  3.26389
# Loss after epoch 39950  is  3.2564242
# Loss after epoch 40000  is  3.249023
# Loss after epoch 40050  is  3.241634
# Loss after epoch 40100  is  3.234246
# Loss after epoch 40150  is  3.2268953
# Loss after epoch 40200  is  3.2195675
# Loss after epoch 40250  is  3.2122684
# Loss after epoch 40300  is  3.204982
# Loss after epoch 40350  is  3.1977193
# Loss after epoch 40400  is  3.1904945
# Loss after epoch 40450  is  3.1832929
# Loss after epoch 40500  is  3.1760912
# Loss after epoch 40550  is  3.1689296
# Loss after epoch 40600  is  3.1617935
# Loss after epoch 40650  is  3.154663
# Loss after epoch 40700  is  3.1475654
# Loss after epoch 40750  is  3.1405013
# Loss after epoch 40800  is  3.1334581
# Loss after epoch 40850  is  3.1264124
# Loss after epoch 40900  is  3.119403
# Loss after epoch 40950  is  3.1124296
# Loss after epoch 41000  is  3.105474
# Loss after epoch 41050  is  3.0985177
# Loss after epoch 41100  is  3.0915956
# Loss after epoch 41150  is  3.08471
# Loss after epoch 41200  is  3.0778368
# Loss after epoch 41250  is  3.070974
# Loss after epoch 41300  is  3.064148
# Loss after epoch 41350  is  3.0573587
# Loss after epoch 41400  is  3.0505638
# Loss after epoch 41450  is  3.043782
# Loss after epoch 41500  is  3.037052
# Loss after epoch 41550  is  3.0303416
# Loss after epoch 41600  is  3.0236287
# Loss after epoch 41650  is  3.0169375
# Loss after epoch 41700  is  3.0102992
# Loss after epoch 41750  is  3.0036612
# Loss after epoch 41800  is  2.9970381
# Loss after epoch 41850  is  2.9904356
# Loss after epoch 41900  is  2.9838748
# Loss after epoch 41950  is  2.977328
# Loss after epoch 42000  is  2.970777
# Loss after epoch 42050  is  2.9642692
# Loss after epoch 42100  is  2.9577904
# Loss after epoch 42150  is  2.9513233
# Loss after epoch 42200  is  2.944865
# Loss after epoch 42250  is  2.9384418
# Loss after epoch 42300  is  2.9320383
# Loss after epoch 42350  is  2.9256525
# Loss after epoch 42400  is  2.9192712
# Loss after epoch 42450  is  2.9129303
# Loss after epoch 42500  is  2.906612
# Loss after epoch 42550  is  2.900305
# Loss after epoch 42600  is  2.8940043
# Loss after epoch 42650  is  2.8877406
# Loss after epoch 42700  is  2.88151
# Loss after epoch 42750  is  2.8752854
# Loss after epoch 42800  is  2.8690624
# Loss after epoch 42850  is  2.8628871
# Loss after epoch 42900  is  2.8567216
# Loss after epoch 42950  is  2.8505726
# Loss after epoch 43000  is  2.8444383
# Loss after epoch 43050  is  2.8383405
# Loss after epoch 43100  is  2.8322573
# Loss after epoch 43150  is  2.8261843
# Loss after epoch 43200  is  2.820124
# Loss after epoch 43250  is  2.8141017
# Loss after epoch 43300  is  2.8080924
# Loss after epoch 43350  is  2.8021011
# Loss after epoch 43400  is  2.796126
# Loss after epoch 43450  is  2.7901597
# Loss after epoch 43500  is  2.784241
# Loss after epoch 43550  is  2.77833
# Loss after epoch 43600  is  2.7724216
# Loss after epoch 43650  is  2.7665343
# Loss after epoch 43700  is  2.7606905
# Loss after epoch 43750  is  2.7548506
# Loss after epoch 43800  is  2.7490275
# Loss after epoch 43850  is  2.74321
# Loss after epoch 43900  is  2.7374384
# Loss after epoch 43950  is  2.731678
# Loss after epoch 44000  is  2.7259188
# Loss after epoch 44050  is  2.7201762
# Loss after epoch 44100  is  2.7144783
# Loss after epoch 44150  is  2.7087862
# Loss after epoch 44200  is  2.7031074
# Loss after epoch 44250  is  2.6974444
# Loss after epoch 44300  is  2.691811
# Loss after epoch 44350  is  2.6862006
# Loss after epoch 44400  is  2.6805887
# Loss after epoch 44450  is  2.6749854
# Loss after epoch 44500  is  2.669429
# Loss after epoch 44550  is  2.663887
# Loss after epoch 44600  is  2.6583564
# Loss after epoch 44650  is  2.6528318
# Loss after epoch 44700  is  2.6473289
# Loss after epoch 44750  is  2.641865
# Loss after epoch 44800  is  2.6364043
# Loss after epoch 44850  is  2.6309505
# Loss after epoch 44900  is  2.6255212
# Loss after epoch 44950  is  2.620123
# Now testing the model in the test set
# The final loss is:  3.9603198
